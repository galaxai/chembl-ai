# %%
import pyarrow.dataset as ds

# %%
! ls ../data/chembl_36/exports/assay
# Out:
# assays-0.parquet

# %%
path = "../data/chembl_36/exports/assay/"

# %%
dataset = ds.dataset(path, format="parquet")

# %%
dataset

# %%
dataset.schema
# Out:
# assay_id: int64
# assay_type: string
# assay_organism: string
# assay_tax_id: int64
# tid: int64
# doc_id: int64
# chembl_id: string

# %%
dataset.head(5)
# Out:
# pyarrow.Table
# assay_id: int64
# assay_type: string
# assay_organism: string
# assay_tax_id: int64
# tid: int64
# doc_id: int64
# chembl_id: string
# ----
# assay_id: [[5,6,7,8,9]]
# assay_type: [["F","F","F","F","F"]]
# assay_organism: [["Homo sapiens","Homo sapiens","Mus musculus","Homo sapiens","Homo sapiens"]]
# assay_tax_id: [[9606,9606,10090,9606,9606]]
# tid: [[80001,80001,80001,80001,80001]]
# doc_id: [[17430,17430,13799,17774,3801]]
# chembl_id: [["CHEMBL615121","CHEMBL615122","CHEMBL615123","CHEMBL615124","CHEMBL615125"]]
